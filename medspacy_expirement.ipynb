# %%
import spacy
import scispacy
import medspacy
#T121	Pharmacologic Substance
#T047	Disease or Syndrome
#T046   Pathologic Function

# %%
nlp = spacy.load("en_core_sci_lg")
doc = nlp("Alterations in the hypocretin receptor 2 and preprohypocretin genes produce narcolepsy in some animals.")

# %%
import spacy
import scispacy

from scispacy.linking import EntityLinker

nlp = spacy.load("en_core_sci_lg")

# This line takes a while, because we have to download ~1GB of data
# and load a large JSON file (the knowledge base). Be patient!
# Thankfully it should be faster after the first time you use it, because
# the downloads are cached.
# NOTE: The resolve_abbreviations parameter is optional, and requires that
# the AbbreviationDetector pipe has already been added to the pipeline. Adding
# the AbbreviationDetector pipe and setting resolve_abbreviations to True means
# that linking will only be performed on the long form of abbreviations.
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": False, "linker_name": "mesh"})

doc = nlp("Spinal and bulbar muscular atrophy (SBMA) is an \
           inherited motor neuron disease caused by the expansion \
           of a polyglutamine tract within the androgen receptor (AR). \
           SBMA can be caused by this easily.")

# Let's look at a random entity!
entity = doc.ents[1]

print("Name: ", entity)

# Each entity is linked to UMLS with a score
# (currently just char-3gram matching).
linker = nlp.get_pipe("scispacy_linker")
for umls_ent in entity._.kb_ents:
	print(linker.kb.cui_to_entity[umls_ent[0]])
# Out:
# /Users/njsaquer/opt/anaconda3/envs/med_env/lib/python3.10/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/njsaquer/opt/anaconda3/envs/med_env/lib/python3.10/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Name:  bulbar muscular atrophy
# CUI: C1839259, Name: Bulbo-Spinal Atrophies, X-Linked
# ...

# %%
    big_text = """  is a 60 y.o. female

    Complete blood count

    Lab Results
    Component	Value	Date/Time
        WBC	6.5	09/22/2023 04:20 AM
        RBC	3.48 (L)	09/22/2023 04:20 AM
        HGB	10.9 (L)	09/22/2023 04:20 AM
        HGB	12.6	09/11/2023 02:42 AM
        HCT	33.4 (L)	09/22/2023 04:20 AM
        MCV	96.0	09/22/2023 04:20 AM
        MCH	31.3	09/22/2023 04:20 AM
        MCHC	32.6	09/22/2023 04:20 AM
        PLT	148	09/22/2023 04:20 AM
        PLT	154	09/11/2023 02:42 AM
        RDW	12.7	09/22/2023 04:20 AM
        NEUTROPHIL	5.48	09/22/2023 04:20 AM
        LYMPHOCYTE	0.59 (L)	09/22/2023 04:20 AM
        EOSINOPHIL	0.00	09/22/2023 04:20 AM


    Chemistry
    Lab Results
    Component	Value	Date/Time
        NA	142	09/22/2023 04:20 AM
        K	9 (L)	09/22/2023 04:20 AM
        CL	108 (H)	09/22/2023 04:20 AM
        CO2	24	09/22/2023 04:20 AM
        CA	8.1 (L)	09/22/2023 04:20 AM
        CA	8.7 (L)	09/11/2023 02:42 AM
        BUN	14	09/22/2023 04:20 AM
        CREAT	0.79	09/22/2023 04:20 AM
        GFR	>60	09/22/2023 04:20 AM
        GFR	>60	09/11/2023 02:42 AM
        GLUCOSE	151 (H)	09/22/2023 04:20 AM
        TOTALPROTEIN	5.3 (L)	09/22/2023 04:20 AM
        ALBUMIN	3.3 (L)	09/22/2023 04:20 AM
        BILITOTAL	0.3	09/22/2023 04:20 AM
        LIPASE	142	04/12/2015 05:01 AM
        ALKPHOS	27 (L)	09/22/2023 04:20 AM
    Sig: Take by mouth daily.
    Elmiron 100 mg Capsule	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 CAPSULE(100 MG) BY MOUTH THREE TIMES DAILY
    HYDROcodone-acetaminophen (NORCO) 5-325 mg tablet	Unknown		No	No
    Sig: Take 1 Tablet by mouth every 4 hours as needed for Pain, Moderate. Max Daily Amount: 6 Tablets
    Lyrica 150 mg Capsule	Past Week		No	Yes
    Sig: TAKE 1 CAPSULE BY MOUTH AT BEDTIME
    Nebulizer Accessories Kit			Yes	No
    Sig: Use as directed with nebulizer
    albuterol sulfate 90 mcg/Actuation inhaler	Past Month		Yes	Yes
    Sig: Take 2 Puffs by inhalation every 6 hours as needed.
    alpelisib 300 mg/day (150 mg x 2) Tablet	Past Week		No	Yes
    Sig: Take 300 mg by mouth daily.
    alpelisib, PROS, 50 mg Tablet	Past Week		No	Yes
    Sig: Take 1 Tablet by mouth daily for 7 days.
    ascorbic acid, vitamin C, (VITAMIN C) 500 mg tablet	9/9/2023 at 0800		Yes	Yes
    Sig: Take 500 mg by mouth daily.
    atorvastatin (LIPITOR) 80 mg tablet	Unknown		No	No
    Sig: TAKE 1 TABLET(80 MG) BY MOUTH DAILY WITH SUPPER
    azelastine (ASTELIN) 137 mcg/actuation nasal spray	Unknown		No	No
    Sig: USE 2 SPRAYS IN EACH NOSTRIL TWICE DAILY
    cannabidiol, CBD, product, for documentation purposes,	> Month		Yes	No
    Sig: Take by mouth 2 times daily.
    cetirizine (ZyrTEC) 10 mg tablet	9/9/2023 at 0800		Yes	Yes
    Sig: Take 10 mg by mouth daily.
    cholecalciferol, vitamin D3, 1,000 unit	Unknown		Yes	No
    Sig: Take 1,000 Units by mouth daily.
    clonazePAM (KlonoPIN) 0.5 mg Tablet	Past Week		No	Yes
    Sig: TAKE 1 TABLET BY MOUTH EVERY NIGHT AT BEDTIME FOR INSOMNIA
    cyclobenzaprine (FLEXERIL) 10 mg tablet	Past Week		No	Yes
    Sig: TAKE 1 TABLET BY MOUTH EVERY EVENING FOR SPASM
    denosumab (XGEVA) 120 mg/1.7 mL (70 mg/mL) Solution	> Month		Yes	No
    Sig: Inject 120 mg by subcutaneous injection every 30 days.
    dexAMETHasone (DECADRON) 0.5 mg/5 mL Solution	Unknown		No	No
    Sig: Take 5 ml and swish and spit 4 times daily while on the Affinitor.
    docusate sodium (COLACE) 50 mg capsule	Unknown		No	No
    Sig: Take 1 Capsule (50 mg) by mouth 2 times daily.
    hydrOXYzine HCL (ATARAX) 25 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: Take 1 Tablet (25 mg) by mouth daily.
    levoFLOXacin (LEVAQUIN) 250 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: Take 1 Tablet (250 mg) by mouth daily.
    methenamine hippurate (HIPREX) 1 gram Tablet	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 TABLET(1000 MG) BY MOUTH TWICE DAILY
    methocarbamoL (ROBAXIN) 750 mg tablet	Past Week		No	Yes
    Sig: TAKE 1 TABLET BY MOUTH THREE TIMES DAILY AS NEEDED FOR SPASM
    methylPREDNISolone (MEDROL DOSPACK) 4 mg Tablets, Dose Pack	Unknown		No	No
    Sig: As instructed.
    mometasone (Asmanex Twisthaler) 220 mcg Aerosol Powdr Breath Activated	Unknown		Yes	No
    Sig: Take 1 Puff by inhalation 2 times daily.
    naloxone (NARCAN) 4 mg/spray Spray, Non-Aerosol	Unknown		No	No
    Sig: EMERGENCY USE ONLY: Administer 1 spray (4 mg) in one nostril one time. May repeat in alternating nostrils every 2-3 min until responsive or EMS arrives.
    nebulizer			Yes	No
    Sig: Length of need  99 months
    Nebulizer with compressor, Kit: Permanent Nebulizer Kit, 1 per 6 months, filters , areosol mask: Yes. Name of Medication duoneb
    ondansetron (Zofran) 4 mg Tablet	Past Week		No	Yes
    Sig: Take 1 Tablet (4 mg) by mouth every 6 hours as needed for Nausea/Emesis.
    oxyBUTYnin (DITROPAN) 5 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 TABLET(5 MG) BY MOUTH THREE TIMES DAILY AS NEEDED FOR BLADDER
    pantoprazole (PROTONIX) 40 mg Tablet, Delayed Release (E.C.)	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 TABLET BY MOUTH DAILY
    phenazopyridine 200 mg tablet	Unknown		No	No
    Sig: Take 1 Tablet (200 mg) by mouth 3 times daily as needed for Pain.
    predniSONE (DELTASONE) 10 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: Take 1 Tablet (10 mg) by mouth 3 times daily with meals.
    promethazine (PHENERGAN) 25 mg tablet	> Month		Yes	No
    Sig: Take 25 mg by mouth every 6 hours as needed.
    spironolactone (ALDACTONE) 100 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 TABLET(100 MG) BY MOUTH TWICE DAILY
    triamcinolone acetonide (KENALOG) 0.5 % Cream	Unknown		No	No
    Sig: Apply to affected areas of back twice daily for two weeks for flares.

    Facility-Administered Medications: None


    Current Facility-Administered Medications
    Medication	Dose	Route	Frequency	Provider	Last Rate	Last Admin
    �	potassium chloride (KLOR-CON) SR tablet 20 mEq	 20 mEq	Oral	BID WITH meals	Dailey, Zachariah, MD	 	20 mEq at 09/12/23 1603
    �	predniSONE (DELTASONE) tablet 65 mg	 65 mg	Oral	daily WITH breakfast	Balasundaram, Chitra, MD	 	65 mg at 09/12/23 1603
    �	famotidine (PEPCID) tablet 20 mg	 20 mg	Oral	BID	Balasundaram, Chitra, MD	 	 
    �	loperamide (IMODIUM) capsule 2 mg	 2 mg	Oral	QID PRN	Dailey, Zachariah, MD	 	2 mg at 09/12/23 1603
    �	clonazePAM (KlonoPIN) tablet 0.5 mg	 0.5 mg	Oral	daily BEDTIME	Zguri, Liridon, MD	 	0.5 mg at 09/11/23 2139
    �	HYDROcodone-acetaminophen (NORCO) 5-325 mg per tablet 1 Tablet	 1 Tablet	Oral	every 4 hours PRN	Zguri, Liridon, MD	 	 
    �	oxyBUTYnin (DITROPAN) tablet 5 mg	 5 mg	Oral	TID PRN	Zguri, Liridon, MD	 	5 mg at 09/12/23 1136
    �	spironolactone (ALDACTONE) tablet 100 mg	 100 mg	Oral	BID	Zguri, Liridon, MD	 	100 mg at 09/12/23 0815
        HGBA1C	5.1	08/16/2023 08:33 AM
        LDLCALC	153 (H)	05/11/2022 08:42 AM


    Lab Results
    Component	Value	Date/Time
        TRIGLYCERIDE	151 (H)	05/11/2022 08:42 AM
        TSH	0.86	03/23/2023 11:14 AM


    Toxicology
    No results found for: "ETHANOL", "ACETAMINOPHE", "SALICYLATE"

    Vitamins
    Lab Results
    Component	Value	Date/Time
        VITAMINDTO	38	07/31/2018 12:38 PM


    Tumor markers
    No results found for: "AFPTM"

    Virology
    No results found for: "CD4", "HIV1RNACOPIE", "HEPAIGM", "HEPBCORIGM", "HEPBSAG", "HEPCAB" 


    GIPATHOGEN
    No results found for: "CLOSTRIDIU"




    Principal Problem:
    Morbilliform rash
    Active Problems:
    Gastroesophageal reflux disease without esophagitis
    Cancer, metastatic to bone
    Coronary artery disease involving native coronary artery of native heart without angina pectoris
    Mixed hyperlipidemia
    Drug reaction
    


    Vitals:
        09/12/23 1547
    BP:	101/49
    Pulse:	
    Resp:	17
    Temp:	98.2 �F (36.8 �C)
    SpO2:	95%



    Prior to Admission Medications
    Prescriptions	Last Dose	Informant	Patient Reported?	Taking?
    CALCIUM CARBONATE-VITAMIN D3 ORAL	9/9/2023 at 0800		Yes	Yes
    Sig: Take by mouth daily.
    Elmiron 100 mg Capsule	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 CAPSULE(100 MG) BY MOUTH THREE TIMES DAILY
    HYDROcodone-acetaminophen (NORCO) 5-325 mg tablet	Unknown		No	No
    Sig: Take 1 Tablet by mouth every 4 hours as needed for Pain, Moderate. Max Daily Amount: 6 Tablets
    Lyrica 150 mg Capsule	Past Week		No	Yes
    Sig: TAKE 1 CAPSULE BY MOUTH AT BEDTIME
    Nebulizer Accessories Kit			Yes	No
    Sig: Use as directed with nebulizer
    albuterol sulfate 90 mcg/Actuation inhaler	Past Month		Yes	Yes
    Sig: Take 2 Puffs by inhalation every 6 hours as needed.
    alpelisib 300 mg/day (150 mg x 2) Tablet	Past Week		No	Yes
    Sig: Take 300 mg by mouth daily.
    alpelisib, PROS, 50 mg Tablet	Past Week		No	Yes
    Sig: Take 1 Tablet by mouth daily for 7 days.
    ascorbic acid, vitamin C, (VITAMIN C) 500 mg tablet	9/9/2023 at 0800		Yes	Yes
    Sig: Take 500 mg by mouth daily.
    atorvastatin (LIPITOR) 80 mg tablet	Unknown		No	No
    Sig: TAKE 1 TABLET(80 MG) BY MOUTH DAILY WITH SUPPER
    azelastine (ASTELIN) 137 mcg/actuation nasal spray	Unknown		No	No
    Sig: USE 2 SPRAYS IN EACH NOSTRIL TWICE DAILY
    cannabidiol, CBD, product, for documentation purposes,	> Month		Yes	No
    Sig: Take by mouth 2 times daily.
    cetirizine (ZyrTEC) 10 mg tablet	9/9/2023 at 0800		Yes	Yes
    Sig: Take 10 mg by mouth daily.
    cholecalciferol, vitamin D3, 1,000 unit	Unknown		Yes	No
    Sig: Take 1,000 Units by mouth daily.
    clonazePAM (KlonoPIN) 0.5 mg Tablet	Past Week		No	Yes
    Sig: TAKE 1 TABLET BY MOUTH EVERY NIGHT AT BEDTIME FOR INSOMNIA
    cyclobenzaprine (FLEXERIL) 10 mg tablet	Past Week		No	Yes
    Sig: TAKE 1 TABLET BY MOUTH EVERY EVENING FOR SPASM
    denosumab (XGEVA) 120 mg/1.7 mL (70 mg/mL) Solution	> Month		Yes	No
    Sig: Inject 120 mg by subcutaneous injection every 30 days.
    dexAMETHasone (DECADRON) 0.5 mg/5 mL Solution	Unknown		No	No
    Sig: Take 5 ml and swish and spit 4 times daily while on the Affinitor.
    docusate sodium (COLACE) 50 mg capsule	Unknown		No	No
    Sig: Take 1 Capsule (50 mg) by mouth 2 times daily.
    hydrOXYzine HCL (ATARAX) 25 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: Take 1 Tablet (25 mg) by mouth daily.
    levoFLOXacin (LEVAQUIN) 250 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: Take 1 Tablet (250 mg) by mouth daily.
    methenamine hippurate (HIPREX) 1 gram Tablet	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 TABLET(1000 MG) BY MOUTH TWICE DAILY
    methocarbamoL (ROBAXIN) 750 mg tablet	Past Week		No	Yes
    Sig: TAKE 1 TABLET BY MOUTH THREE TIMES DAILY AS NEEDED FOR SPASM
    methylPREDNISolone (MEDROL DOSPACK) 4 mg Tablets, Dose Pack	Unknown		No	No
    Sig: As instructed.
    mometasone (Asmanex Twisthaler) 220 mcg Aerosol Powdr Breath Activated	Unknown		Yes	No
    Sig: Take 1 Puff by inhalation 2 times daily.
    naloxone (NARCAN) 4 mg/spray Spray, Non-Aerosol	Unknown		No	No
    Sig: EMERGENCY USE ONLY: Administer 1 spray (4 mg) in one nostril one time. May repeat in alternating nostrils every 2-3 min until responsive or EMS arrives.
    nebulizer			Yes	No
    Sig: Length of need  99 months
    Nebulizer with compressor, Kit: Permanent Nebulizer Kit, 1 per 6 months, filters , areosol mask: Yes. Name of Medication duoneb
    ondansetron (Zofran) 4 mg Tablet	Past Week		No	Yes
    Sig: Take 1 Tablet (4 mg) by mouth every 6 hours as needed for Nausea/Emesis.
    oxyBUTYnin (DITROPAN) 5 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 TABLET(5 MG) BY MOUTH THREE TIMES DAILY AS NEEDED FOR BLADDER
    pantoprazole (PROTONIX) 40 mg Tablet, Delayed Release (E.C.)	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 TABLET BY MOUTH DAILY
    phenazopyridine 200 mg tablet	Unknown		No	No
    Sig: Take 1 Tablet (200 mg) by mouth 3 times daily as needed for Pain.
    predniSONE (DELTASONE) 10 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: Take 1 Tablet (10 mg) by mouth 3 times daily with meals.
    promethazine (PHENERGAN) 25 mg tablet	> Month		Yes	No
    Sig: Take 25 mg by mouth every 6 hours as needed.
    spironolactone (ALDACTONE) 100 mg tablet	9/9/2023 at 0800		No	Yes
    Sig: TAKE 1 TABLET(100 MG) BY MOUTH TWICE DAILY
    triamcinolone acetonide (KENALOG) 0.5 % Cream	Unknown		No	No
    Sig: Apply to affected areas of back twice daily for two weeks for flares.

    Facility-Administered Medications: None


    Current Facility-Administered Medications
    Medication	Dose	Route	Frequency	Provider	Last Rate	Last Admin
    �	[DISCONTINUED] vancomycin (VANCOCIN) 1,000 mg in sodium chloride 0.9% 250 mL IVPB	 1,000 mg	IV	every 12 hours	Snider, Jessica Nicole, DO	 	Stopped at 09/12/23 0036
    �	sodium chloride flush injection 5 mL	 5 mL	IV	every 12 hours (2 times daily)	Plate, Rachel, MD	 	5 mL at 09/12/23 0836
    �	sodium chloride flush injection 5 mL	 5 mL	IV	see admin instructions	Plate, Rachel, MD	 	 
    �	sodium chloride 0.9 % 250 mL flush bag 25 mL	 25 mL	IV	see admin instructions	Plate, Rachel, MD	 	 
    �	dextrose 5 % in water 250 mL flush bag 25 mL	 25 mL	IV	see admin instructions	Plate, Rachel, MD	 	 


    Pneumonia

            
    unstable angina
                    


    Hyperkalemia



    """

    newtext = """


    Lower GI bleeding


    Rheumatoid arthritis involving multiple sites with positive rheumatoid factor
    Essential hypertension
    Type 2 diabetes mellitus with diabetic nephropathy, without long-term current use of insulin
    Mixed hyperlipidemia
    COPD (chronic obstructive pulmonary disease)"""

# %%
doc = nlp(newtext)
names = []
#can mess with the kb names to make case insensitive. need to see how to mess with matching algorithm
#could be worthwhile making a custom matcher(based on kaggle bookmark)or the MESH vocab instead of UMLS
for j in range(len(doc.ents)):
	entity = doc.ents[j]

	full_match_ents = []
	for i in range(len(entity._.umls_ents)):
		#filter for match and disease type
		if entity._.umls_ents[i][1]:
			full_match_ents.append(entity._.umls_ents[i])
	if len(full_match_ents) > 0 and  entity.text not in names:
		print("Name: ", entity)
		print("CUI: ", full_match_ents[0][0], end = "\n\n")
		#print("Type", linker.kb.cui_to_entity[full_match_ents[0][0]].types, end = "\n\n")
		names.append(entity.text)
# Out:
# Name:  Problem
# CUI:  C0037431
#
# Name:  Lower
# CUI:  C0330090
#
# Name:  Problems
# CUI:  C0037431
#
# Name:  Rheumatoid arthritis
# CUI:  C0003873
#
# Name:  positive rheumatoid factor
# CUI:  C0035448
#
# Name:  Essential hypertension
# CUI:  C0085580
#
# Name:  Type 2 diabetes mellitus
# CUI:  C0011860
#
# Name:  diabetic nephropathy
# CUI:  C0011881
#
# Name:  long-term
# CUI:  C0023977
#
# Name:  insulin
# CUI:  C0021641
#
# Name:  COPD
# CUI:  C0024117
#
# Name:  chronic obstructive pulmonary disease
# CUI:  C0024117

# %%
import ctakes_parser as parser
import pandas as pd

# %%
parser.ctakes_parser.parse_file(file_path = "/Users/njsaquer/Downloads/EM2IM-INATOR/test.xml")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/pg/86qb6g7d4qz60qgc27gj44bc0000gn/T/ipykernel_46342/2505716030.py in ?()
# ----> 1 parser.ctakes_parser.parse_file(file_path = "/Users/njsaquer/Downloads/EM2IM-INATOR/test.xml")
#
# ~/opt/anaconda3/envs/med_env/lib/python3.10/site-packages/ctakes_parser/ctakes_parser.py in ?(file_path)
#     110
#     111     results = results.to_dataframe()
#     112     positions = positions.to_dataframe()
#     113
# --> 114     positions.set_index('pos_start', drop=False, inplace=True)
#     115     positions.index.name = 'index'
#     116
#     117     def _positional_search(df):
#
# ~/opt/anaconda3/envs/med_env/lib/python3.10/site-packages/pandas/core/frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5865                     if not found:
#    5866                         missing.append(col)
#    5867
# ...
